# %% [markdown]
# ## Cross sectional regression

# %%
import pandas as pd 
import numpy as np

# %%
working_df = pd.read_csv("working_sample_1.csv")

# %%
working_df_clean = working_df.drop(columns="Unnamed: 0")
print(working_df_clean.head())
# Out:
#          date  isin  cs_change  delta lr  change_in_10y_bond  change_in_slope  \
# 0  2022-11-30     0   -0.00267  0.000058            -0.00028         -0.00395
# 1  2022-12-31     0   -0.00102  0.000058             0.00517          0.00171
# 2  2023-01-31     0   -0.00020  0.000024            -0.00310         -0.00158
# 3  2023-02-28     0    0.00077  0.000024             0.00167         -0.00069
# 4  2023-03-31     0    0.00259  0.000024            -0.00229         -0.00179
#
#    smi_return  v3x_change rating  maturity  cpi_change  unempl_change  \
# 0    0.027314   -0.030361    AAA      10.0      0.0040            0.1
# 1   -0.036456   -0.005036    AAA      10.0     -0.2283            0.1
# 2    0.050557    0.005429    AAA      10.0      0.6286            0.1
# 3   -0.016747   -0.001126    AAA      10.0      0.7838            0.0
# 4    0.000710   -0.016202    AAA      10.0      0.1623           -0.1
#
#    gdp_change  liquidity  credit_rating_numeric     rating_class  \
# 0    0.260500      0.665                      1  AAA class bonds
# 1    0.260500      0.862                      1  AAA class bonds
# 2    0.061917      0.432                      1  AAA class bonds
# 3    0.061917      0.423                      1  AAA class bonds
# 4    0.061917      0.417                      1  AAA class bonds
#
#   maturity_bucket
# 0     Medium-Term
# 1     Medium-Term
# 2     Medium-Term
# 3     Medium-Term
# 4     Medium-Term

# %% [markdown]
# ### Long-term

# %%
df_long_term = working_df_clean[working_df_clean['maturity_bucket'] == "Long-Term"]

print(df_long_term)
# Out:
#              date  isin  cs_change  delta lr  change_in_10y_bond  \
# 121    2022-07-31     3    0.00094 -0.000117            -0.00584
# 122    2022-08-31     3    0.00059 -0.000117             0.00363
# 123    2022-09-30     3    0.00201 -0.000117             0.00394
# 124    2022-10-31     3   -0.00188 -0.000117            -0.00081
# 125    2022-11-30     3   -0.00552 -0.000117            -0.00028
# ...           ...   ...        ...       ...                 ...
# 36215  2024-08-31   527    0.00001  0.000040             0.00007
# 36216  2024-09-30   527    0.00016  0.000040            -0.00054
# 36217  2024-10-31   527   -0.00030  0.000040             0.00007
# 36218  2024-11-30   527   -0.00011  0.000040            -0.00177
# 36219  2024-12-31   527   -0.00010  0.000040             0.00075
#
#        change_in_slope  smi_return  v3x_change rating  maturity  cpi_change  \
# 121           -0.00517    0.036985   -0.058189    AAA      25.0     -0.0396
# 122           -0.00251   -0.026443    0.029616    AAA      25.0      0.2755
# 123            0.00243   -0.055640    0.018258    AAA      25.0     -0.1840
# 124            0.00148    0.053141   -0.030715    AAA      25.0      0.0561
# 125           -0.00395    0.027314   -0.030361    AAA      25.0      0.0040
# ...                ...         ...         ...    ...       ...         ...
# 36215          0.00104    0.009627    0.012917     AA      12.0     -0.0153
# 36216          0.00076   -0.021762   -0.001398     AA      12.0     -0.3139
# 36217          0.00050   -0.031382    0.035715     AA      12.0     -0.1357
# 36218          0.00034   -0.002438   -0.042992     AA      12.0     -0.1445
# 36219          0.00168   -0.013979    0.002462     AA      12.0     -0.0588
#
#        unempl_change  gdp_change  liquidity  credit_rating_numeric  \
# 121             0.10     0.26050    0.70000                      1
# 122             0.10     0.26050    0.50000                      1
# 123            -0.10     0.26050    0.60001                      1
# 124            -0.10     0.26050    0.50000                      1
# 125             0.10     0.26050    0.64999                      1
# ...              ...         ...        ...                    ...
# 36215           0.57     0.10575    0.31675                      3
# 36216           0.28     0.10575    0.35630                      3
# 36217          -0.09     0.10575    0.32390                      3
# 36218          -0.42     0.10575    0.38250                      3
# 36219          -0.06     0.10575    0.41580                      3
#
#           rating_class maturity_bucket
# 121    AAA class bonds       Long-Term
# 122    AAA class bonds       Long-Term
# 123    AAA class bonds       Long-Term
# 124    AAA class bonds       Long-Term
# 125    AAA class bonds       Long-Term
# ...                ...             ...
# 36215   AA class bonds       Long-Term
# 36216   AA class bonds       Long-Term
# 36217   AA class bonds       Long-Term
# 36218   AA class bonds       Long-Term
# 36219   AA class bonds       Long-Term
#
# [16933 rows x 17 columns]

# %%
from linearmodels.panel import PooledOLS
import statsmodels.api as sm

# %%
results_by_rating = {}
r_squared_table = {}

coef_table = pd.DataFrame()
for group_name, group_data in df_long_term.groupby('rating_class'):
    y_group = group_data['cs_change']
    x_group = group_data[['delta lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change','cpi_change', 'unempl_change', 'gdp_change','liquidity']]
    x_group = sm.add_constant(x_group)
    model1 = sm.OLS(y_group, x_group).fit()
    
    coef = model1.params
    coef.name = group_name

    coef_table = pd.concat([coef_table, coef], axis=1)
    
    print(f"\n\nResult for {group_name}")
    print(model1.summary)
    print(model1.summary())
    results_by_rating[group_name] = model1
    
    r_squared_table[group_name] = model1.rsquared
# Out:
# Result for A class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x117542360>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     7.351
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           2.01e-10
# Time:                        16:09:00   Log-Likelihood:                 5561.4
# No. Observations:                 996   AIC:                        -1.110e+04
# Df Residuals:                     986   BIC:                        -1.105e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -5.465e-06   6.33e-05     -0.086      0.931      -0.000       0.000
# delta lr               0.0014      0.002      0.739      0.460      -0.002       0.005
# change_in_10y_bond    -0.0364      0.020     -1.780      0.075      -0.077       0.004
# change_in_slope        0.1128      0.028      4.003      0.000       0.058       0.168
# smi_return            -0.0039      0.001     -3.267      0.001      -0.006      -0.002
# v3x_change            -0.0005      0.001     -0.531      0.596      -0.002       0.001
# cpi_change             0.0005      0.000      4.449      0.000       0.000       0.001
# unempl_change      -8.165e-06      0.000     -0.067      0.947      -0.000       0.000
# gdp_change         -1.908e-05      0.000     -0.108      0.914      -0.000       0.000
# liquidity          -3.616e-05      5e-05     -0.723      0.470      -0.000     6.2e-05
# ==============================================================================
# Omnibus:                      280.809   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4050.386
# Skew:                           0.877   Prob(JB):                         0.00
# Kurtosis:                      12.722   Cond. No.                     1.51e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for AA class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x1173c7260>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                     33.19
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           8.00e-57
# Time:                        16:09:00   Log-Likelihood:                 20856.
# No. Observations:                3988   AIC:                        -4.169e+04
# Df Residuals:                    3978   BIC:                        -4.163e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0002   3.98e-05     -4.911      0.000      -0.000      -0.000
# delta lr               0.0025      0.002      1.577      0.115      -0.001       0.006
# change_in_10y_bond    -0.0854      0.014     -6.103      0.000      -0.113      -0.058
# change_in_slope        0.1665      0.019      8.652      0.000       0.129       0.204
# smi_return            -0.0050      0.001     -5.938      0.000      -0.007      -0.003
# v3x_change             0.0005      0.001      0.727      0.467      -0.001       0.002
# cpi_change             0.0007   8.32e-05      8.458      0.000       0.001       0.001
# unempl_change         -0.0002   8.82e-05     -2.716      0.007      -0.000   -6.67e-05
# gdp_change          4.423e-05      0.000      0.354      0.723      -0.000       0.000
# liquidity              0.0001   2.61e-05      4.965      0.000    7.84e-05       0.000
# ==============================================================================
# Omnibus:                     4307.937   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2031180.180
# Skew:                           4.732   Prob(JB):                         0.00
# Kurtosis:                     113.155   Cond. No.                     1.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for AAA class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x117903680>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     34.26
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           3.60e-60
# Time:                        16:09:00   Log-Likelihood:                 51741.
# No. Observations:               10681   AIC:                        -1.035e+05
# Df Residuals:                   10671   BIC:                        -1.034e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0001   3.59e-05     -3.446      0.001      -0.000   -5.34e-05
# delta lr               0.0024      0.002      1.498      0.134      -0.001       0.006
# change_in_10y_bond    -0.0813      0.013     -6.469      0.000      -0.106      -0.057
# change_in_slope        0.1885      0.017     11.002      0.000       0.155       0.222
# smi_return            -0.0041      0.001     -5.444      0.000      -0.006      -0.003
# v3x_change            -0.0003      0.001     -0.484      0.628      -0.002       0.001
# cpi_change             0.0007   7.42e-05      9.264      0.000       0.001       0.001
# unempl_change         -0.0002   7.91e-05     -2.162      0.031      -0.000   -1.59e-05
# gdp_change          2.661e-05      0.000      0.233      0.816      -0.000       0.000
# liquidity            6.62e-05   2.49e-05      2.654      0.008    1.73e-05       0.000
# ==============================================================================
# Omnibus:                     9516.291   Durbin-Watson:                   2.624
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1762021118.170
# Skew:                          -2.220   Prob(JB):                         0.00
# Kurtosis:                    1992.776   Cond. No.                     1.51e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for Not rated bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x117901a90>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     10.41
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           1.23e-15
# Time:                        16:09:00   Log-Likelihood:                 7028.0
# No. Observations:                1268   AIC:                        -1.404e+04
# Df Residuals:                    1258   BIC:                        -1.398e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -9.077e-05    5.4e-05     -1.682      0.093      -0.000    1.51e-05
# delta lr               0.0008      0.003      0.288      0.774      -0.005       0.007
# change_in_10y_bond    -0.0808      0.018     -4.402      0.000      -0.117      -0.045
# change_in_slope        0.1047      0.025      4.210      0.000       0.056       0.153
# smi_return            -0.0029      0.001     -2.618      0.009      -0.005      -0.001
# v3x_change             0.0009      0.001      0.975      0.330      -0.001       0.003
# cpi_change             0.0007      0.000      6.350      0.000       0.000       0.001
# unempl_change      -1.433e-05      0.000     -0.127      0.899      -0.000       0.000
# gdp_change         -3.792e-05      0.000     -0.222      0.824      -0.000       0.000
# liquidity           4.178e-05   4.15e-05      1.007      0.314   -3.96e-05       0.000
# ==============================================================================
# Omnibus:                      225.005   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4393.410
# Skew:                           0.144   Prob(JB):                         0.00
# Kurtosis:                      12.114   Cond. No.                     1.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create R² DataFrame
r_squared_table = pd.Series(r_squared_table, name='R_squared')
# Print
print(r_squared_table)
# Out:
# A class bonds      0.062882
# AA class bonds     0.069844
# AAA class bonds    0.028082
# Not rated bonds    0.069309
# Name: R_squared, dtype: float64

# %% [markdown]
# ### Medium-term

# %%
df_medium_term = working_df_clean[working_df_clean['maturity_bucket'] == "Medium-Term"]

print(df_medium_term)
# Out:
#              date  isin  cs_change  delta lr  change_in_10y_bond  \
# 0      2022-11-30     0   -0.00267  0.000058            -0.00028
# 1      2022-12-31     0   -0.00102  0.000058             0.00517
# 2      2023-01-31     0   -0.00020  0.000024            -0.00310
# 3      2023-02-28     0    0.00077  0.000024             0.00167
# 4      2023-03-31     0    0.00259  0.000024            -0.00229
# ...           ...   ...        ...       ...                 ...
# 36120  2024-08-31   526    0.00158 -0.042684             0.00007
# 36121  2024-09-30   526    0.00052 -0.042684            -0.00054
# 36122  2024-10-31   526   -0.00631 -0.042684             0.00007
# 36123  2024-11-30   526   -0.00187 -0.042684            -0.00177
# 36124  2024-12-31   526    0.00341 -0.042684             0.00075
#
#        change_in_slope  smi_return  v3x_change rating  maturity  cpi_change  \
# 0             -0.00395    0.027314   -0.030361    AAA      10.0      0.0040
# 1              0.00171   -0.036456   -0.005036    AAA      10.0     -0.2283
# 2             -0.00158    0.050557    0.005429    AAA      10.0      0.6286
# 3             -0.00069   -0.016747   -0.001126    AAA      10.0      0.7838
# 4             -0.00179    0.000710   -0.016202    AAA      10.0      0.1623
# ...                ...         ...         ...    ...       ...         ...
# 36120          0.00104    0.009627    0.012917    AAA      10.0     -0.0153
# 36121          0.00076   -0.021762   -0.001398    AAA      10.0     -0.3139
# 36122          0.00050   -0.031382    0.035715    AAA      10.0     -0.1357
# 36123          0.00034   -0.002438   -0.042992    AAA      10.0     -0.1445
# 36124          0.00168   -0.013979    0.002462    AAA      10.0     -0.0588
#
#        unempl_change  gdp_change  liquidity  credit_rating_numeric  \
# 0               0.10    0.260500    0.66500                      1
# 1               0.10    0.260500    0.86200                      1
# 2               0.10    0.061917    0.43200                      1
# 3               0.00    0.061917    0.42300                      1
# 4              -0.10    0.061917    0.41700                      1
# ...              ...         ...        ...                    ...
# 36120           0.57    0.105750    0.14460                      1
# 36121           0.28    0.105750    0.08580                      1
# 36122          -0.09    0.105750    0.06420                      1
# 36123          -0.42    0.105750    0.05145                      1
# 36124          -0.06    0.105750    0.04860                      1
#
#           rating_class maturity_bucket
# 0      AAA class bonds     Medium-Term
# 1      AAA class bonds     Medium-Term
# 2      AAA class bonds     Medium-Term
# 3      AAA class bonds     Medium-Term
# 4      AAA class bonds     Medium-Term
# ...                ...             ...
# 36120  AAA class bonds     Medium-Term
# 36121  AAA class bonds     Medium-Term
# 36122  AAA class bonds     Medium-Term
# 36123  AAA class bonds     Medium-Term
# 36124  AAA class bonds     Medium-Term
#
# [18176 rows x 17 columns]

# %%
results_by_rating = {}
r_squared_table = {}

coef_table = pd.DataFrame()
for group_name, group_data in df_medium_term.groupby('rating_class'):
    y_group = group_data['cs_change']
    x_group = group_data[['delta lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change','liquidity']]
    x_group = sm.add_constant(x_group)
    model1 = sm.OLS(y_group, x_group).fit()
    
    coef = model1.params
    coef.name = group_name

    coef_table = pd.concat([coef_table, coef], axis=1)
    
    print(f"\n\nResult for {group_name}")
    print(model1.summary)
    print(model1.summary())
    results_by_rating[group_name] = model1
    
    r_squared_table[group_name] = model1.rsquared
    

coef_table = coef_table.T
# Out:
# Result for A class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x116415640>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     25.05
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           4.52e-42
# Time:                        16:09:00   Log-Likelihood:                 17786.
# No. Observations:                3352   AIC:                        -3.555e+04
# Df Residuals:                    3342   BIC:                        -3.549e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0002   4.57e-05     -4.164      0.000      -0.000      -0.000
# delta lr               0.0012      0.002      0.745      0.456      -0.002       0.004
# change_in_10y_bond    -0.0635      0.014     -4.451      0.000      -0.091      -0.036
# change_in_slope        0.1385      0.019      7.121      0.000       0.100       0.177
# smi_return            -0.0044      0.001     -5.174      0.000      -0.006      -0.003
# v3x_change             0.0001      0.001      0.175      0.861      -0.001       0.002
# cpi_change             0.0007   8.41e-05      7.728      0.000       0.000       0.001
# unempl_change         -0.0003   8.89e-05     -2.855      0.004      -0.000   -7.94e-05
# gdp_change             0.0001      0.000      0.954      0.340      -0.000       0.000
# liquidity              0.0001   4.07e-05      3.465      0.001    6.12e-05       0.000
# ==============================================================================
# Omnibus:                     1067.686   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            86160.740
# Skew:                           0.579   Prob(JB):                         0.00
# Kurtosis:                      27.811   Cond. No.                     1.39e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for AA class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x11791a510>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     20.23
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           1.21e-33
# Time:                        16:09:00   Log-Likelihood:                 20964.
# No. Observations:                4005   AIC:                        -4.191e+04
# Df Residuals:                    3995   BIC:                        -4.185e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0002   4.22e-05     -4.642      0.000      -0.000      -0.000
# delta lr               0.0019      0.002      1.143      0.253      -0.001       0.005
# change_in_10y_bond    -0.0452      0.014     -3.182      0.001      -0.073      -0.017
# change_in_slope        0.1150      0.019      5.904      0.000       0.077       0.153
# smi_return            -0.0035      0.001     -4.140      0.000      -0.005      -0.002
# v3x_change             0.0007      0.001      0.949      0.342      -0.001       0.002
# cpi_change             0.0005   8.31e-05      6.101      0.000       0.000       0.001
# unempl_change         -0.0002   8.66e-05     -2.240      0.025      -0.000   -2.42e-05
# gdp_change          1.315e-05      0.000      0.104      0.917      -0.000       0.000
# liquidity              0.0002   2.98e-05      5.135      0.000    9.47e-05       0.000
# ==============================================================================
# Omnibus:                     3232.286   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4451580.125
# Skew:                           2.470   Prob(JB):                         0.00
# Kurtosis:                     166.254   Cond. No.                     1.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for AAA class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x1179019d0>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     48.91
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           4.00e-86
# Time:                        16:09:00   Log-Likelihood:                 34225.
# No. Observations:                6392   AIC:                        -6.843e+04
# Df Residuals:                    6382   BIC:                        -6.836e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0002   2.93e-05     -5.874      0.000      -0.000      -0.000
# delta lr               0.0016      0.001      1.398      0.162      -0.001       0.004
# change_in_10y_bond    -0.0795      0.010     -7.985      0.000      -0.099      -0.060
# change_in_slope        0.1673      0.014     12.255      0.000       0.141       0.194
# smi_return            -0.0034      0.001     -5.796      0.000      -0.005      -0.002
# v3x_change             0.0002      0.000      0.341      0.733      -0.001       0.001
# cpi_change             0.0007   5.82e-05     11.366      0.000       0.001       0.001
# unempl_change         -0.0001   6.04e-05     -2.328      0.020      -0.000   -2.22e-05
# gdp_change          2.061e-05   8.86e-05      0.233      0.816      -0.000       0.000
# liquidity              0.0001   2.39e-05      5.510      0.000    8.47e-05       0.000
# ==============================================================================
# Omnibus:                     3728.087   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           475552.542
# Skew:                           1.819   Prob(JB):                         0.00
# Kurtosis:                      45.099   Cond. No.                     1.45e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for BBB/BB/B bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x11793e1e0>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.127
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):              0.340
# Time:                        16:09:00   Log-Likelihood:                 4325.9
# No. Observations:                 993   AIC:                            -8632.
# Df Residuals:                     983   BIC:                            -8583.
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               2.918e-05      0.000      0.139      0.890      -0.000       0.000
# delta lr              -0.0018      0.007     -0.248      0.804      -0.016       0.012
# change_in_10y_bond    -0.1281      0.070     -1.829      0.068      -0.266       0.009
# change_in_slope        0.1114      0.096      1.161      0.246      -0.077       0.300
# smi_return            -0.0097      0.004     -2.377      0.018      -0.018      -0.002
# v3x_change            -0.0032      0.003     -0.940      0.348      -0.010       0.003
# cpi_change             0.0004      0.000      0.876      0.381      -0.000       0.001
# unempl_change         -0.0002      0.000     -0.539      0.590      -0.001       0.001
# gdp_change         -3.084e-05      0.001     -0.051      0.959      -0.001       0.001
# liquidity           4.772e-05      0.000      0.217      0.828      -0.000       0.000
# ==============================================================================
# Omnibus:                      974.101   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           533997.638
# Skew:                          -3.626   Prob(JB):                         0.00
# Kurtosis:                     116.374   Cond. No.                     1.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for Not rated bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x1179240e0>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     6.796
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           9.88e-10
# Time:                        16:09:00   Log-Likelihood:                 15215.
# No. Observations:                3434   AIC:                        -3.041e+04
# Df Residuals:                    3424   BIC:                        -3.035e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -5.306e-05   9.03e-05     -0.588      0.557      -0.000       0.000
# delta lr               0.0015      0.004      0.347      0.729      -0.007       0.010
# change_in_10y_bond    -0.0512      0.034     -1.488      0.137      -0.119       0.016
# change_in_slope        0.2548      0.047      5.394      0.000       0.162       0.347
# smi_return            -0.0052      0.002     -2.581      0.010      -0.009      -0.001
# v3x_change            -0.0008      0.002     -0.507      0.612      -0.004       0.002
# cpi_change             0.0005      0.000      2.553      0.011       0.000       0.001
# unempl_change      -7.896e-05      0.000     -0.380      0.704      -0.000       0.000
# gdp_change            -0.0002      0.000     -0.637      0.524      -0.001       0.000
# liquidity           5.722e-05   7.17e-05      0.798      0.425   -8.33e-05       0.000
# ==============================================================================
# Omnibus:                     2440.597   Durbin-Watson:                   2.805
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        167805920.751
# Skew:                          -1.265   Prob(JB):                         0.00
# Kurtosis:                    1085.949   Cond. No.                     1.44e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create R² DataFrame
r_squared_table = pd.Series(r_squared_table, name='R_squared')
# Print
print(r_squared_table)
# Out:
# A class bonds      0.063199
# AA class bonds     0.043587
# AAA class bonds    0.064526
# BBB/BB/B bonds     0.010211
# Not rated bonds    0.017550
# Name: R_squared, dtype: float64

# %% [markdown]
# ### Short-term

# %%
df_short_term = working_df_clean[working_df_clean['maturity_bucket'] == "Short-Term"]

print(df_short_term.head())
# Out:
#             date  isin  cs_change  delta lr  change_in_10y_bond  \
# 1060  2021-05-31    18    0.00009 -0.000107             0.00045
# 1061  2021-06-30    18    0.00009 -0.000107            -0.00069
# 1062  2021-07-31    18   -0.00024 -0.000107            -0.00135
# 1063  2021-08-31    18    0.00024 -0.000107             0.00043
# 1064  2021-09-30    18    0.00083 -0.000107             0.00145
#
#       change_in_slope  smi_return  v3x_change rating  maturity  cpi_change  \
# 1060          0.00041    0.035981   -0.008706   BBB+       3.0      0.2664
# 1061         -0.00054    0.044217   -0.001625   BBB+       3.0      0.0748
# 1062         -0.00140    0.014473    0.003346   BBB+       3.0     -0.0857
# 1063          0.00078    0.023998   -0.004311   BBB+       3.0      0.2481
# 1064          0.00087   -0.063935    0.038714   BBB+       3.0      0.0176
#
#       unempl_change  gdp_change  liquidity  credit_rating_numeric  \
# 1060           -0.3    0.464417       0.73                      8
# 1061           -0.1    0.464417       0.62                      8
# 1062            0.3    0.464417       0.64                      8
# 1063            0.0    0.464417       0.71                      8
# 1064           -0.2    0.464417       0.56                      8
#
#         rating_class maturity_bucket
# 1060  BBB/BB/B bonds      Short-Term
# 1061  BBB/BB/B bonds      Short-Term
# 1062  BBB/BB/B bonds      Short-Term
# 1063  BBB/BB/B bonds      Short-Term
# 1064  BBB/BB/B bonds      Short-Term

# %%
results_by_rating = {}
r_squared_table = {}

coef_table = pd.DataFrame()
for group_name, group_data in df_short_term.groupby('rating_class'):
    y_group = group_data['cs_change']
    x_group = group_data[['delta lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change','cpi_change', 'unempl_change', 'gdp_change','liquidity']]
    x_group = sm.add_constant(x_group)
    model1 = sm.OLS(y_group, x_group).fit()
    
    coef = model1.params
    coef.name = group_name

    coef_table = pd.concat([coef_table, coef], axis=1)
    
    print(f"\n\nResult for {group_name}")
    print(model1.summary)
    print(model1.summary())
    results_by_rating[group_name] = model1
    
    r_squared_table[group_name] = model1.rsquared
    

coef_table = coef_table.T
# Out:
# Result for A class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x117542360>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     2.753
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):            0.00669
# Time:                        16:09:00   Log-Likelihood:                 510.64
# No. Observations:                 104   AIC:                            -1001.
# Df Residuals:                      94   BIC:                            -974.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0005      0.000     -1.040      0.301      -0.001       0.000
# delta lr               0.0341      0.019      1.762      0.081      -0.004       0.073
# change_in_10y_bond    -0.3876      0.120     -3.226      0.002      -0.626      -0.149
# change_in_slope        0.5365      0.164      3.279      0.001       0.212       0.861
# smi_return            -0.0098      0.007     -1.328      0.187      -0.024       0.005
# v3x_change             0.0015      0.006      0.240      0.811      -0.011       0.014
# cpi_change             0.0009      0.001      1.251      0.214      -0.001       0.002
# unempl_change         -0.0001      0.001     -0.133      0.895      -0.002       0.002
# gdp_change             0.0006      0.001      0.525      0.601      -0.002       0.003
# liquidity              0.0004      0.000      1.856      0.067   -3.02e-05       0.001
# ==============================================================================
# Omnibus:                      103.940   Durbin-Watson:                   2.314
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2060.429
# Skew:                          -3.059   Prob(JB):                         0.00
# Kurtosis:                      23.930   Cond. No.                     1.82e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for AA class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x11624dd00>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     3.532
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           0.000427
# Time:                        16:09:00   Log-Likelihood:                 1088.3
# No. Observations:                 218   AIC:                            -2157.
# Df Residuals:                     208   BIC:                            -2123.
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               4.606e-05      0.000      0.200      0.842      -0.000       0.001
# delta lr               0.1099      0.084      1.304      0.194      -0.056       0.276
# change_in_10y_bond    -0.0980      0.080     -1.229      0.220      -0.255       0.059
# change_in_slope        0.3432      0.109      3.153      0.002       0.129       0.558
# smi_return            -0.0014      0.005     -0.308      0.758      -0.011       0.008
# v3x_change             0.0011      0.004      0.276      0.783      -0.007       0.009
# cpi_change             0.0018      0.000      3.878      0.000       0.001       0.003
# unempl_change          0.0009      0.000      1.770      0.078   -9.65e-05       0.002
# gdp_change            -0.0003      0.001     -0.350      0.727      -0.002       0.001
# liquidity             -0.0003      0.000     -1.507      0.133      -0.001    9.89e-05
# ==============================================================================
# Omnibus:                       72.554   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              761.036
# Skew:                           0.930   Prob(JB):                    5.53e-166
# Kurtosis:                      11.962   Cond. No.                     1.39e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for AAA class bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x1179248f0>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     1.553
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):              0.137
# Time:                        16:09:00   Log-Likelihood:                 572.13
# No. Observations:                 132   AIC:                            -1124.
# Df Residuals:                     122   BIC:                            -1095.
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0015      0.001     -1.955      0.053      -0.003    1.82e-05
# delta lr               0.0709      0.093      0.762      0.448      -0.113       0.255
# change_in_10y_bond    -0.2492      0.202     -1.235      0.219      -0.648       0.150
# change_in_slope        0.4587      0.277      1.657      0.100      -0.089       1.007
# smi_return             0.0016      0.012      0.132      0.895      -0.022       0.025
# v3x_change            -0.0092      0.009     -1.007      0.316      -0.027       0.009
# cpi_change             0.0035      0.001      2.892      0.005       0.001       0.006
# unempl_change          0.0008      0.001      0.614      0.540      -0.002       0.003
# gdp_change            -0.0011      0.002     -0.699      0.486      -0.004       0.002
# liquidity              0.0014      0.001      2.104      0.037    8.45e-05       0.003
# ==============================================================================
# Omnibus:                       97.806   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2207.531
# Skew:                           2.079   Prob(JB):                         0.00
# Kurtosis:                      22.598   Cond. No.                     1.54e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for BBB/BB/B bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x117925730>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     2.606
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):            0.00716
# Time:                        16:09:00   Log-Likelihood:                 1247.6
# No. Observations:                 219   AIC:                            -2475.
# Df Residuals:                     209   BIC:                            -2441.
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0002      0.000     -1.200      0.232      -0.000       0.000
# delta lr               0.0038      0.003      1.219      0.224      -0.002       0.010
# change_in_10y_bond    -0.0751      0.039     -1.931      0.055      -0.152       0.002
# change_in_slope        0.1004      0.053      1.880      0.062      -0.005       0.206
# smi_return            -0.0017      0.002     -0.752      0.453      -0.006       0.003
# v3x_change            -0.0002      0.002     -0.133      0.895      -0.004       0.003
# cpi_change             0.0009      0.000      3.694      0.000       0.000       0.001
# unempl_change         -0.0002      0.000     -0.698      0.486      -0.001       0.000
# gdp_change            -0.0002      0.000     -0.567      0.571      -0.001       0.000
# liquidity              0.0002      0.000      1.065      0.288      -0.000       0.001
# ==============================================================================
# Omnibus:                       23.771   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              108.812
# Skew:                           0.102   Prob(JB):                     2.35e-24
# Kurtosis:                       6.447   Cond. No.                     1.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Result for Not rated bonds
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x11793d2e0>>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              cs_change   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     4.015
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           6.02e-05
# Time:                        16:09:00   Log-Likelihood:                 2508.6
# No. Observations:                 438   AIC:                            -4997.
# Df Residuals:                     428   BIC:                            -4956.
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -1.311e-05   7.82e-05     -0.168      0.867      -0.000       0.000
# delta lr               0.0008      0.003      0.297      0.767      -0.005       0.006
# change_in_10y_bond    -0.1115      0.027     -4.127      0.000      -0.165      -0.058
# change_in_slope        0.1121      0.038      2.981      0.003       0.038       0.186
# smi_return            -0.0018      0.002     -1.116      0.265      -0.005       0.001
# v3x_change            -0.0007      0.001     -0.502      0.616      -0.003       0.002
# cpi_change             0.0006      0.000      3.882      0.000       0.000       0.001
# unempl_change         -0.0002      0.000     -1.266      0.206      -0.001       0.000
# gdp_change            -0.0002      0.000     -1.033      0.302      -0.001       0.000
# liquidity          -4.962e-06   4.79e-05     -0.104      0.918   -9.91e-05    8.92e-05
# ==============================================================================
# Omnibus:                       50.890   Durbin-Watson:                   1.699
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              359.776
# Skew:                           0.001   Prob(JB):                     7.51e-79
# Kurtosis:                       7.440   Cond. No.                     1.80e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create R² DataFrame
r_squared_table = pd.Series(r_squared_table, name='R_squared')
# Print
print(r_squared_table)
# Out:
# A class bonds      0.208628
# AA class bonds     0.132566
# AAA class bonds    0.102762
# BBB/BB/B bonds     0.100911
# Not rated bonds    0.077863
# Name: R_squared, dtype: float64
