# %% [markdown]
# # Fixed effect regression

# %%
import pandas as pd 
import numpy as np
from linearmodels.panel import PanelOLS
from linearmodels.panel import PooledOLS
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
panel_data = pd.read_csv("panel_data.csv")
print(panel_data.head())
# Out:
#          date  isin  cs_change  delta lr  change_in_10y_bond  change_in_slope  \
# 0  2015-01-31     8   -0.00063  0.000000            -0.00395          0.00006
# 1  2015-01-31    16    0.00008  0.001782            -0.00395          0.00006
# 2  2015-01-31    19   -0.00046  0.000000            -0.00395          0.00006
# 3  2015-01-31    25   -0.00077  0.000209            -0.00395          0.00006
# 4  2015-01-31    31   -0.00078  0.000000            -0.00395          0.00006
#
#    smi_return  v3x_change rating   maturity  cpi_change  unempl_change  \
# 0   -0.068915    0.045699    AAA   8.000000     -0.4006            0.3
# 1   -0.068915    0.045699     NR  10.000000     -0.4006            0.3
# 2   -0.068915    0.045699     NR   8.000000     -0.4006            0.3
# 3   -0.068915    0.045699     A-   6.833333     -0.4006            0.3
# 4   -0.068915    0.045699     AA  10.000000     -0.4006            0.3
#
#    gdp_change  liquidity  credit_rating_numeric     rating_class  \
# 0    0.131167     0.8302                      1  AAA class bonds
# 1    0.131167     0.6042                     15  Not rated bonds
# 2    0.131167     1.5405                     15  Not rated bonds
# 3    0.131167     0.9983                      7    A class bonds
# 4    0.131167     1.0000                      3   AA class bonds
#
#   maturity_bucket
# 0     Medium-Term
# 1     Medium-Term
# 2     Medium-Term
# 3     Medium-Term
# 4     Medium-Term

# %%
panel_data = panel_data.rename(columns={'delta lr':'change_in_lr'})

# %%
panel_data_adj = panel_data.set_index(['date', 'isin']).sort_index()
print(panel_data_adj.head())
# Out:
#                  cs_change  change_in_lr  change_in_10y_bond  change_in_slope  \
# date       isin
# 2015-01-31 8      -0.00063      0.000000            -0.00395          0.00006
#            16      0.00008      0.001782            -0.00395          0.00006
#            19     -0.00046      0.000000            -0.00395          0.00006
#            25     -0.00077      0.000209            -0.00395          0.00006
#            31     -0.00078      0.000000            -0.00395          0.00006
#
#                  smi_return  v3x_change rating   maturity  cpi_change  \
# date       isin
# 2015-01-31 8      -0.068915    0.045699    AAA   8.000000     -0.4006
#            16     -0.068915    0.045699     NR  10.000000     -0.4006
#            19     -0.068915    0.045699     NR   8.000000     -0.4006
#            25     -0.068915    0.045699     A-   6.833333     -0.4006
#            31     -0.068915    0.045699     AA  10.000000     -0.4006
#
#                  unempl_change  gdp_change  liquidity  credit_rating_numeric  \
# date       isin
# 2015-01-31 8               0.3    0.131167     0.8302                      1
#            16              0.3    0.131167     0.6042                     15
#            19              0.3    0.131167     1.5405                     15
#            25              0.3    0.131167     0.9983                      7
#            31              0.3    0.131167     1.0000                      3
#
#                     rating_class maturity_bucket
# date       isin
# 2015-01-31 8     AAA class bonds     Medium-Term
#            16    Not rated bonds     Medium-Term
#            19    Not rated bonds     Medium-Term
#            25      A class bonds     Medium-Term
#            31     AA class bonds     Medium-Term

# %%
X = panel_data_adj[['change_in_lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change', 'liquidity']]
y = panel_data_adj['cs_change']
X = sm.add_constant(X)

model = PanelOLS(y, X, time_effects=True).fit()
print(model.summary)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0322
# Estimator:                   PanelOLS   R-squared (Between):              0.0695
# No. Observations:               36220   R-squared (Within):              -0.0034
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0297
# Time:                        17:14:05   Log-likelihood                  1.79e+05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      132.12
# Entities:                         120   P-value                           0.0000
# Avg Obs:                       301.83   Distribution:                 F(9,35683)
# Min Obs:                       45.000
# Max Obs:                       528.00   F-statistic (robust):             132.12
#                                         P-value                           0.0000
# Time periods:                     528   Distribution:                 F(9,35683)
# Avg Obs:                       68.598
# Min Obs:                       22.000
# Max Obs:                       120.00
#
#                                  Parameter Estimates
# ======================================================================================
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# const                 -0.0002  2.294e-05    -9.8692     0.0000     -0.0003     -0.0002
# change_in_lr           0.0017     0.0008     2.1060     0.0352      0.0001      0.0032
# change_in_10y_bond    -0.0783     0.0063    -12.382     0.0000     -0.0907     -0.0659
# change_in_slope        0.1712     0.0086     19.849     0.0000      0.1543      0.1881
# smi_return            -0.0042     0.0004    -11.288     0.0000     -0.0050     -0.0035
# v3x_change            -0.0001     0.0003    -0.4506     0.6523     -0.0008      0.0005
# cpi_change             0.0007  3.722e-05     17.569     0.0000      0.0006      0.0007
# unempl_change         -0.0002  3.893e-05    -4.0395     0.0001     -0.0002  -8.095e-05
# gdp_change          6.603e-05  5.803e-05     1.1378     0.2552  -4.771e-05      0.0002
# liquidity              0.0002   1.96e-05     9.5147     0.0000      0.0001      0.0002
# ======================================================================================
#
# F-test for Poolability: 0.3362
# P-value: 1.0000
# Distribution: F(527,35683)
#
# Included effects: Time

# %% [markdown]
# ### Fixed effect regression by classes

# %%
results_by_rating = {}
r_squared_table = {}

coef_table = pd.DataFrame()
for group_name, group_data in panel_data_adj.groupby('rating_class'):
    y_group = group_data['cs_change']
    x_group = group_data[['change_in_lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change', 'liquidity']]
    x_group = sm.add_constant(x_group)  
    model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
    
    coef = model.params
    coef.name = group_name
    coef_table = pd.concat([coef_table, coef], axis=1)
    
    
    print(f"\n\nResult for {group_name}")
    print(model.summary)
    
  
    results_by_rating[group_name] = model
    r_squared_table[group_name] = model.rsquared
    

coef_table = coef_table.T
# Out:
# Result for A class bonds
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0020
# Estimator:                   PanelOLS   R-squared (Between):              0.0033
# No. Observations:                4452   R-squared (Within):               0.0020
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0018
# Time:                        17:14:05   Log-likelihood                 2.481e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.3483
# Entities:                         120   P-value                           0.0130
# Avg Obs:                       37.100   Distribution:                  F(2,4330)
# Min Obs:                       6.0000
# Max Obs:                       65.000   F-statistic (robust):             4.3483
#                                         P-value                           0.0130
# Time periods:                      65   Distribution:                  F(2,4330)
# Avg Obs:                       68.492
# Min Obs:                       23.000
# Max Obs:                       120.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const        -7.802e-05  2.574e-05    -3.0307     0.0025     -0.0001  -2.755e-05
# change_in_lr     0.0008     0.0012     0.6505     0.5154     -0.0015      0.0030
# liquidity     7.603e-05  2.636e-05     2.8843     0.0039   2.435e-05      0.0001
# ================================================================================
#
# F-test for Poolability: 26.008
# P-value: 0.0000
# Distribution: F(119,4330)
#
# Included effects: Entity
#
#
# Result for AA class bonds
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0027
# Estimator:                   PanelOLS   R-squared (Between):              0.0106
# No. Observations:                8211   R-squared (Within):               0.0027
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0043
# Time:                        17:14:05   Log-likelihood                 4.445e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      10.786
# Entities:                         120   P-value                           0.0000
# Avg Obs:                       68.425   Distribution:                  F(2,8089)
# Min Obs:                       9.0000
# Max Obs:                       122.00   F-statistic (robust):             10.786
#                                         P-value                           0.0000
# Time periods:                     122   Distribution:                  F(2,8089)
# Avg Obs:                       67.303
# Min Obs:                       22.000
# Max Obs:                       120.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const        -9.968e-05  2.033e-05    -4.9032     0.0000     -0.0001  -5.983e-05
# change_in_lr     0.0008     0.0011     0.7686     0.4421     -0.0013      0.0030
# liquidity     7.896e-05  1.731e-05     4.5625     0.0000   4.503e-05      0.0001
# ================================================================================
#
# F-test for Poolability: 37.205
# P-value: 0.0000
# Distribution: F(119,8089)
#
# Included effects: Entity
#
#
# Result for AAA class bonds
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):              0.0026
# No. Observations:               17205   R-squared (Within):               0.0002
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0007
# Time:                        17:14:05   Log-likelihood                 8.736e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.8764
# Entities:                         120   P-value                           0.1532
# Avg Obs:                       143.38   Distribution:                 F(2,17083)
# Min Obs:                       19.000
# Max Obs:                       257.00   F-statistic (robust):             1.8764
#                                         P-value                           0.1532
# Time periods:                     257   Distribution:                 F(2,17083)
# Avg Obs:                       66.946
# Min Obs:                       23.000
# Max Obs:                       120.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const        -4.914e-05  1.914e-05    -2.5667     0.0103  -8.667e-05  -1.161e-05
# change_in_lr     0.0007     0.0011     0.6418     0.5210     -0.0015      0.0029
# liquidity     3.211e-05  1.759e-05     1.8252     0.0680  -2.374e-06   6.659e-05
# ================================================================================
#
# F-test for Poolability: 40.614
# P-value: 0.0000
# Distribution: F(119,17083)
#
# Included effects: Entity
#
#
# Result for BBB/BB/B bonds
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                     8.949e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0025
# No. Observations:                1212   R-squared (Within):            8.949e-05
# Date:                Thu, May 15 2025   R-squared (Overall):             -0.0001
# Time:                        17:14:05   Log-likelihood                    5465.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.0488
# Entities:                         120   P-value                           0.9524
# Avg Obs:                       10.100   Distribution:                  F(2,1090)
# Min Obs:                       2.0000
# Max Obs:                       16.000   F-statistic (robust):             0.0488
#                                         P-value                           0.9524
# Time periods:                      16   Distribution:                  F(2,1090)
# Avg Obs:                       75.750
# Min Obs:                       24.000
# Max Obs:                       120.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const         7.841e-05     0.0002     0.4881     0.6256     -0.0002      0.0004
# change_in_lr    -0.0012     0.0068    -0.1763     0.8601     -0.0145      0.0121
# liquidity    -5.531e-05     0.0002    -0.2707     0.7867     -0.0005      0.0003
# ================================================================================
#
# F-test for Poolability: 1.3076
# P-value: 0.0192
# Distribution: F(119,1090)
#
# Included effects: Entity
#
#
# Result for Not rated bonds
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                     7.752e-06
# Estimator:                   PanelOLS   R-squared (Between):              0.0002
# No. Observations:                5140   R-squared (Within):            7.752e-06
# Date:                Thu, May 15 2025   R-squared (Overall):           4.801e-05
# Time:                        17:14:05   Log-likelihood                 2.397e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.0195
# Entities:                         120   P-value                           0.9807
# Avg Obs:                       42.833   Distribution:                  F(2,5018)
# Min Obs:                       9.0000
# Max Obs:                       68.000   F-statistic (robust):             0.0195
#                                         P-value                           0.9807
# Time periods:                      68   Distribution:                  F(2,5018)
# Avg Obs:                       75.588
# Min Obs:                       25.000
# Max Obs:                       120.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const        -2.635e-05  5.062e-05    -0.5207     0.6026     -0.0001   7.288e-05
# change_in_lr    -0.0003     0.0031    -0.1091     0.9131     -0.0065      0.0058
# liquidity     7.635e-06  4.794e-05     0.1593     0.8735  -8.635e-05      0.0001
# ================================================================================
#
# F-test for Poolability: 5.9586
# P-value: 0.0000
# Distribution: F(119,5018)
#
# Included effects: Entity
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3221789431.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3221789431.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3221789431.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3221789431.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3221789431.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()

# %%
print(coef_table)
# Out:
#                     const  change_in_lr  liquidity
# A class bonds   -0.000078      0.000759   0.000076
# AA class bonds  -0.000100      0.000836   0.000079
# AAA class bonds -0.000049      0.000711   0.000032
# BBB/BB/B bonds   0.000078     -0.001194  -0.000055
# Not rated bonds -0.000026     -0.000341   0.000008

# %%
# Create R² DataFrame
r_squared_table = pd.Series(r_squared_table, name='R_squared')
# Print
print(r_squared_table)
# Out:
# A class bonds      0.002004
# AA class bonds     0.002660
# AAA class bonds    0.000220
# BBB/BB/B bonds     0.000089
# Not rated bonds    0.000008
# Name: R_squared, dtype: float64

# %% [markdown]
# ### By maturities

# %%
results_by_maturity = {}
r_squared_table = {}

coef_table = pd.DataFrame()
for group_name, group_data in panel_data_adj.groupby('maturity_bucket'):
    y_group = group_data['cs_change']
    x_group = group_data[['change_in_lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change', 'liquidity']]
    x_group = sm.add_constant(x_group)  
    model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
    
    coef = model.params
    coef.name = group_name
    coef_table = pd.concat([coef_table, coef], axis=1)
    
    
    print(f"\n\nResult for {group_name}")
    print(model.summary)
    
  
    results_by_maturity[group_name] = model
    r_squared_table[group_name] = model.rsquared
    

coef_table = coef_table.T
# Out:
# Result for Long-Term
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):              0.0023
# No. Observations:               16933   R-squared (Within):               0.0003
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0007
# Time:                        17:14:05   Log-likelihood                 8.607e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.3264
# Entities:                         120   P-value                           0.0977
# Avg Obs:                       141.11   Distribution:                 F(2,16811)
# Min Obs:                       19.000
# Max Obs:                       259.00   F-statistic (robust):             2.3264
#                                         P-value                           0.0977
# Time periods:                     259   Distribution:                 F(2,16811)
# Avg Obs:                       65.378
# Min Obs:                       23.000
# Max Obs:                       120.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const        -4.862e-05  1.894e-05    -2.5664     0.0103  -8.575e-05  -1.149e-05
# change_in_lr     0.0010     0.0011     0.9423     0.3460     -0.0011      0.0032
# liquidity     3.193e-05  1.646e-05     1.9401     0.0524  -3.288e-07   6.418e-05
# ================================================================================
#
# F-test for Poolability: 40.743
# P-value: 0.0000
# Distribution: F(119,16811)
#
# Included effects: Entity
#
#
# Result for Medium-Term
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.0045
# No. Observations:               18176   R-squared (Within):               0.0004
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0010
# Time:                        17:14:05   Log-likelihood                 9.086e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      3.3947
# Entities:                         120   P-value                           0.0336
# Avg Obs:                       151.47   Distribution:                 F(2,18054)
# Min Obs:                       26.000
# Max Obs:                       253.00   F-statistic (robust):             3.3947
#                                         P-value                           0.0336
# Time periods:                     253   Distribution:                 F(2,18054)
# Avg Obs:                       71.842
# Min Obs:                       22.000
# Max Obs:                       120.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const        -6.245e-05  2.075e-05    -3.0097     0.0026     -0.0001  -2.178e-05
# change_in_lr  -8.53e-05     0.0011    -0.0787     0.9372     -0.0022      0.0020
# liquidity     5.351e-05  2.054e-05     2.6049     0.0092   1.325e-05   9.378e-05
# ================================================================================
#
# F-test for Poolability: 35.265
# P-value: 0.0000
# Distribution: F(119,18054)
#
# Included effects: Entity
#
#
# Result for Short-Term
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0015
# Estimator:                   PanelOLS   R-squared (Between):              0.0038
# No. Observations:                1111   R-squared (Within):               0.0015
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0019
# Time:                        17:14:05   Log-likelihood                    5749.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.7369
# Entities:                         112   P-value                           0.4789
# Avg Obs:                       9.9196   Distribution:                   F(2,997)
# Min Obs:                       1.0000
# Max Obs:                       16.000   F-statistic (robust):             0.7369
#                                         P-value                           0.4789
# Time periods:                      16   Distribution:                   F(2,997)
# Avg Obs:                       69.438
# Min Obs:                       26.000
# Max Obs:                       112.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const        -9.082e-05  7.722e-05    -1.1761     0.2398     -0.0002   6.071e-05
# change_in_lr     0.0037     0.0046     0.8067     0.4200     -0.0053      0.0126
# liquidity     6.962e-05  6.615e-05     1.0524     0.2929  -6.019e-05      0.0002
# ================================================================================
#
# F-test for Poolability: 4.0898
# P-value: 0.0000
# Distribution: F(111,997)
#
# Included effects: Entity
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/2396249024.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/2396249024.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/2396249024.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()

# %%
# Create R² DataFrame
r_squared_table = pd.Series(r_squared_table, name='R_squared')
# Print
print(r_squared_table)
# Out:
# Long-Term      0.000277
# Medium-Term    0.000376
# Short-Term     0.001476
# Name: R_squared, dtype: float64

# %% [markdown]
# ### Equity return testing

# %%
eq_data = pd.read_csv("equity_panel.csv")
print(eq_data.head())
# Out:
#    Unnamed: 0        date  isin  cs_change  delta lr  change_in_10y_bond  \
# 0           0  2022-11-30     0   -0.00267  0.000058            -0.00028
# 1           1  2022-12-31     0   -0.00102  0.000058             0.00517
# 2           2  2023-01-31     0   -0.00020  0.000024            -0.00310
# 3           3  2023-02-28     0    0.00077  0.000024             0.00167
# 4           4  2023-03-31     0    0.00259  0.000024            -0.00229
#
#    change_in_slope  smi_return  v3x_change rating  ...  cpi_change  \
# 0         -0.00395    0.027314   -0.030361    AAA  ...      0.0040
# 1          0.00171   -0.036456   -0.005036    AAA  ...     -0.2283
# 2         -0.00158    0.050557    0.005429    AAA  ...      0.6286
# 3         -0.00069   -0.016747   -0.001126    AAA  ...      0.7838
# 4         -0.00179    0.000710   -0.016202    AAA  ...      0.1623
#
#    unempl_change  gdp_change  liquidity  credit_rating_numeric  \
# 0            0.1    0.260500      0.665                      1
# 1            0.1    0.260500      0.862                      1
# 2            0.1    0.061917      0.432                      1
# 3            0.0    0.061917      0.423                      1
# 4           -0.1    0.061917      0.417                      1
#
#       rating_class maturity_bucket stock_return  type_of_firm return_bucket
# 0  AAA class bonds     Medium-Term     0.054598        Public          High
# 1  AAA class bonds     Medium-Term    -0.044278        Public           Low
# 2  AAA class bonds     Medium-Term     0.131504        Public          High
# 3  AAA class bonds     Medium-Term    -0.014803        Public        Medium
# 4  AAA class bonds     Medium-Term     0.002877        Public        Medium
#
# [5 rows x 21 columns]

# %%
eq_data = eq_data.drop(columns='Unnamed: 0')
print(eq_data.head())
# Out:
#          date  isin  cs_change  delta lr  change_in_10y_bond  change_in_slope  \
# 0  2022-11-30     0   -0.00267  0.000058            -0.00028         -0.00395
# 1  2022-12-31     0   -0.00102  0.000058             0.00517          0.00171
# 2  2023-01-31     0   -0.00020  0.000024            -0.00310         -0.00158
# 3  2023-02-28     0    0.00077  0.000024             0.00167         -0.00069
# 4  2023-03-31     0    0.00259  0.000024            -0.00229         -0.00179
#
#    smi_return  v3x_change rating  maturity  cpi_change  unempl_change  \
# 0    0.027314   -0.030361    AAA      10.0      0.0040            0.1
# 1   -0.036456   -0.005036    AAA      10.0     -0.2283            0.1
# 2    0.050557    0.005429    AAA      10.0      0.6286            0.1
# 3   -0.016747   -0.001126    AAA      10.0      0.7838            0.0
# 4    0.000710   -0.016202    AAA      10.0      0.1623           -0.1
#
#    gdp_change  liquidity  credit_rating_numeric     rating_class  \
# 0    0.260500      0.665                      1  AAA class bonds
# 1    0.260500      0.862                      1  AAA class bonds
# 2    0.061917      0.432                      1  AAA class bonds
# 3    0.061917      0.423                      1  AAA class bonds
# 4    0.061917      0.417                      1  AAA class bonds
#
#   maturity_bucket  stock_return type_of_firm return_bucket
# 0     Medium-Term      0.054598       Public          High
# 1     Medium-Term     -0.044278       Public           Low
# 2     Medium-Term      0.131504       Public          High
# 3     Medium-Term     -0.014803       Public        Medium
# 4     Medium-Term      0.002877       Public        Medium

# %%
eq_data_adj = eq_data.set_index(['date', 'isin']).sort_index()
print(eq_data_adj.head())
# Out:
#                  cs_change  delta lr  change_in_10y_bond  change_in_slope  \
# date       isin
# 2015-01-31 8      -0.00063  0.000000            -0.00395          0.00006
#            16      0.00008  0.001782            -0.00395          0.00006
#            19     -0.00046  0.000000            -0.00395          0.00006
#            25     -0.00077  0.000209            -0.00395          0.00006
#            31     -0.00078  0.000000            -0.00395          0.00006
#
#                  smi_return  v3x_change rating   maturity  cpi_change  \
# date       isin
# 2015-01-31 8      -0.068915    0.045699    AAA   8.000000     -0.4006
#            16     -0.068915    0.045699     NR  10.000000     -0.4006
#            19     -0.068915    0.045699     NR   8.000000     -0.4006
#            25     -0.068915    0.045699     A-   6.833333     -0.4006
#            31     -0.068915    0.045699     AA  10.000000     -0.4006
#
#                  unempl_change  gdp_change  liquidity  credit_rating_numeric  \
# date       isin
# 2015-01-31 8               0.3    0.131167     0.8302                      1
#            16              0.3    0.131167     0.6042                     15
#            19              0.3    0.131167     1.5405                     15
#            25              0.3    0.131167     0.9983                      7
#            31              0.3    0.131167     1.0000                      3
#
#                     rating_class maturity_bucket  stock_return type_of_firm  \
# date       isin
# 2015-01-31 8     AAA class bonds     Medium-Term     -0.277778       Public
#            16    Not rated bonds     Medium-Term     -0.046948       Public
#            19    Not rated bonds     Medium-Term      0.015880       Public
#            25      A class bonds     Medium-Term     -0.004638       Public
#            31     AA class bonds     Medium-Term      0.002792       Public
#
#                 return_bucket
# date       isin
# 2015-01-31 8              Low
#            16             Low
#            19          Medium
#            25          Medium
#            31          Medium

# %%
X = eq_data_adj[['delta lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change', 'liquidity']]
y = eq_data_adj['cs_change']
X = sm.add_constant(X)

model = PanelOLS(y, X, entity_effects=True, drop_absorbed=True).fit()
print(model.summary)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0007
# Estimator:                   PanelOLS   R-squared (Between):              0.0058
# No. Observations:               13668   R-squared (Within):               0.0007
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0014
# Time:                        17:14:05   Log-likelihood                 6.883e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.6438
# Entities:                         120   P-value                           0.0096
# Avg Obs:                       113.90   Distribution:                 F(2,13546)
# Min Obs:                       18.000
# Max Obs:                       197.00   F-statistic (robust):             4.6438
#                                         P-value                           0.0096
# Time periods:                     202   Distribution:                 F(2,13546)
# Avg Obs:                       67.663
# Min Obs:                       22.000
# Max Obs:                       120.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const      -7.117e-05  2.208e-05    -3.2227     0.0013     -0.0001  -2.788e-05
# delta lr       0.0001     0.0013     0.0978     0.9221     -0.0024      0.0026
# liquidity   6.109e-05  2.006e-05     3.0451     0.0023   2.177e-05      0.0001
# ==============================================================================
#
# F-test for Poolability: 29.968
# P-value: 0.0000
# Distribution: F(119,13546)
#
# Included effects: Entity
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/2176528053.py:5: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y, X, entity_effects=True, drop_absorbed=True).fit()

# %% [markdown]
# ### By return classes

# %%
results_by_returns = {}
r_squared_table = {}

coef_table = pd.DataFrame()
for group_name, group_data in eq_data_adj.groupby('return_bucket'):
    y_group = group_data['cs_change']
    x_group = group_data[['delta lr', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change', 'liquidity']]
    x_group = sm.add_constant(x_group)  
    model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
    
    coef = model.params
    coef.name = group_name
    coef_table = pd.concat([coef_table, coef], axis=1)
    
    
    print(f"\n\nResult for {group_name}")
    print(model.summary)
    
  
    results_by_returns[group_name] = model
    r_squared_table[group_name] = model.rsquared
    

coef_table = coef_table.T
# Out:
# Result for High
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0008
# Estimator:                   PanelOLS   R-squared (Between):             -0.0157
# No. Observations:                3987   R-squared (Within):               0.0008
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0009
# Time:                        17:14:05   Log-likelihood                  2.23e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.6328
# Entities:                         119   P-value                           0.1955
# Avg Obs:                       33.504   Distribution:                  F(2,3866)
# Min Obs:                       1.0000
# Max Obs:                       127.00   F-statistic (robust):             1.6328
#                                         P-value                           0.1955
# Time periods:                     202   Distribution:                  F(2,3866)
# Avg Obs:                       19.738
# Min Obs:                       1.0000
# Max Obs:                       58.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const      -9.431e-05   2.37e-05    -3.9793     0.0001     -0.0001  -4.784e-05
# delta lr      -0.0019     0.0014    -1.3335     0.1824     -0.0047      0.0009
# liquidity  -2.555e-05   2.11e-05    -1.2109     0.2260  -6.691e-05   1.582e-05
# ==============================================================================
#
# F-test for Poolability: 24.397
# P-value: 0.0000
# Distribution: F(118,3866)
#
# Included effects: Entity
#
#
# Result for Low
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0217
# Estimator:                   PanelOLS   R-squared (Between):             -0.0538
# No. Observations:                3491   R-squared (Within):               0.0217
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0405
# Time:                        17:14:05   Log-likelihood                 1.915e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      37.444
# Entities:                         115   P-value                           0.0000
# Avg Obs:                       30.357   Distribution:                  F(2,3374)
# Min Obs:                       1.0000
# Max Obs:                       142.00   F-statistic (robust):             37.444
#                                         P-value                           0.0000
# Time periods:                     202   Distribution:                  F(2,3374)
# Avg Obs:                       17.282
# Min Obs:                       2.0000
# Max Obs:                       44.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const        2.47e-06  2.816e-05     0.0877     0.9301  -5.274e-05   5.768e-05
# delta lr       0.0029     0.0019     1.5122     0.1306     -0.0009      0.0067
# liquidity      0.0002   2.45e-05     8.5451     0.0000      0.0002      0.0003
# ==============================================================================
#
# F-test for Poolability: 18.997
# P-value: 0.0000
# Distribution: F(114,3374)
#
# Included effects: Entity
#
#
# Result for Medium
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                     6.853e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0092
# No. Observations:                6190   R-squared (Within):            6.853e-05
# Date:                Thu, May 15 2025   R-squared (Overall):           4.744e-05
# Time:                        17:14:05   Log-likelihood                 2.945e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.2079
# Entities:                         120   P-value                           0.8123
# Avg Obs:                       51.583   Distribution:                  F(2,6068)
# Min Obs:                       5.0000
# Max Obs:                       128.00   F-statistic (robust):             0.2079
#                                         P-value                           0.8123
# Time periods:                     202   Distribution:                  F(2,6068)
# Avg Obs:                       30.644
# Min Obs:                       3.0000
# Max Obs:                       107.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const       -9.36e-05  4.414e-05    -2.1205     0.0340     -0.0002  -7.067e-06
# delta lr       0.0005     0.0024     0.2269     0.8205     -0.0041      0.0051
# liquidity   2.515e-05  4.205e-05     0.5981     0.5498  -5.729e-05      0.0001
# ==============================================================================
#
# F-test for Poolability: 7.9395
# P-value: 0.0000
# Distribution: F(119,6068)
#
# Included effects: Entity
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3048476849.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3048476849.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3048476849.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()

# %%
# Create R² DataFrame
r_squared_table = pd.Series(r_squared_table, name='R_squared')
# Print
print(r_squared_table)
# Out:
# High      0.000844
# Low       0.021713
# Medium    0.000069
# Name: R_squared, dtype: float64

# %% [markdown]
# ## Equity testing with market leverage

# %%
eq_data_2 = pd.read_csv("equity_panel2.csv")
print(eq_data_2.head())
# Out:
#    Unnamed: 0        date  isin  cs_change  delta lr  change_in_10y_bond  \
# 0           0  2022-11-30     0   -0.00267  0.000058            -0.00028
# 1           1  2022-12-31     0   -0.00102  0.000058             0.00517
# 2           2  2023-01-31     0   -0.00020  0.000024            -0.00310
# 3           3  2023-02-28     0    0.00077  0.000024             0.00167
# 4           4  2023-03-31     0    0.00259  0.000024            -0.00229
#
#    change_in_slope  smi_return  v3x_change rating  ...  unempl_change  \
# 0         -0.00395    0.027314   -0.030361    AAA  ...            0.1
# 1          0.00171   -0.036456   -0.005036    AAA  ...            0.1
# 2         -0.00158    0.050557    0.005429    AAA  ...            0.1
# 3         -0.00069   -0.016747   -0.001126    AAA  ...            0.0
# 4         -0.00179    0.000710   -0.016202    AAA  ...           -0.1
#
#    gdp_change  liquidity  credit_rating_numeric     rating_class  \
# 0    0.260500      0.665                      1  AAA class bonds
# 1    0.260500      0.862                      1  AAA class bonds
# 2    0.061917      0.432                      1  AAA class bonds
# 3    0.061917      0.423                      1  AAA class bonds
# 4    0.061917      0.417                      1  AAA class bonds
#
#    maturity_bucket stock_return type_of_firm  return_bucket change_in_lmarket
# 0      Medium-Term     0.054598       Public           High          0.431432
# 1      Medium-Term    -0.044278       Public            Low          0.431432
# 2      Medium-Term     0.131504       Public           High         -0.287977
# 3      Medium-Term    -0.014803       Public         Medium         -0.287977
# 4      Medium-Term     0.002877       Public         Medium         -0.287977
#
# [5 rows x 22 columns]

# %%
eq_data_2 = eq_data_2.drop(columns='Unnamed: 0')
print(eq_data_2.head())
# Out:
#          date  isin  cs_change  delta lr  change_in_10y_bond  change_in_slope  \
# 0  2022-11-30     0   -0.00267  0.000058            -0.00028         -0.00395
# 1  2022-12-31     0   -0.00102  0.000058             0.00517          0.00171
# 2  2023-01-31     0   -0.00020  0.000024            -0.00310         -0.00158
# 3  2023-02-28     0    0.00077  0.000024             0.00167         -0.00069
# 4  2023-03-31     0    0.00259  0.000024            -0.00229         -0.00179
#
#    smi_return  v3x_change rating  maturity  ...  unempl_change  gdp_change  \
# 0    0.027314   -0.030361    AAA      10.0  ...            0.1    0.260500
# 1   -0.036456   -0.005036    AAA      10.0  ...            0.1    0.260500
# 2    0.050557    0.005429    AAA      10.0  ...            0.1    0.061917
# 3   -0.016747   -0.001126    AAA      10.0  ...            0.0    0.061917
# 4    0.000710   -0.016202    AAA      10.0  ...           -0.1    0.061917
#
#    liquidity  credit_rating_numeric     rating_class maturity_bucket  \
# 0      0.665                      1  AAA class bonds     Medium-Term
# 1      0.862                      1  AAA class bonds     Medium-Term
# 2      0.432                      1  AAA class bonds     Medium-Term
# 3      0.423                      1  AAA class bonds     Medium-Term
# 4      0.417                      1  AAA class bonds     Medium-Term
#
#   stock_return  type_of_firm return_bucket change_in_lmarket
# 0     0.054598        Public          High          0.431432
# 1    -0.044278        Public           Low          0.431432
# 2     0.131504        Public          High         -0.287977
# 3    -0.014803        Public        Medium         -0.287977
# 4     0.002877        Public        Medium         -0.287977
#
# [5 rows x 21 columns]

# %%
eq_data_2_adj = eq_data_2.set_index(['date', 'isin']).sort_index()
print(eq_data_2_adj.head())
# Out:
#                  cs_change  delta lr  change_in_10y_bond  change_in_slope  \
# date       isin
# 2015-01-31 8      -0.00063  0.000000            -0.00395          0.00006
#            16      0.00008  0.001782            -0.00395          0.00006
#            19     -0.00046  0.000000            -0.00395          0.00006
#            25     -0.00077  0.000209            -0.00395          0.00006
#            56      0.00328  0.000000            -0.00395          0.00006
#
#                  smi_return  v3x_change rating   maturity  cpi_change  \
# date       isin
# 2015-01-31 8      -0.068915    0.045699    AAA   8.000000     -0.4006
#            16     -0.068915    0.045699     NR  10.000000     -0.4006
#            19     -0.068915    0.045699     NR   8.000000     -0.4006
#            25     -0.068915    0.045699     A-   6.833333     -0.4006
#            56     -0.068915    0.045699     AA  15.000000     -0.4006
#
#                  unempl_change  gdp_change  liquidity  credit_rating_numeric  \
# date       isin
# 2015-01-31 8               0.3    0.131167     0.8302                      1
#            16              0.3    0.131167     0.6042                     15
#            19              0.3    0.131167     1.5405                     15
#            25              0.3    0.131167     0.9983                      7
#            56              0.3    0.131167     0.4000                      3
#
#                     rating_class maturity_bucket  stock_return type_of_firm  \
# date       isin
# 2015-01-31 8     AAA class bonds     Medium-Term     -0.277778       Public
#            16    Not rated bonds     Medium-Term     -0.046948       Public
#            19    Not rated bonds     Medium-Term      0.015880       Public
#            25      A class bonds     Medium-Term     -0.004638       Public
#            56     AA class bonds       Long-Term     -0.272135       Public
#
#                 return_bucket  change_in_lmarket
# date       isin
# 2015-01-31 8              Low          -0.694994
#            16             Low           0.277715
#            19          Medium          -0.688464
#            25          Medium          -0.544897
#            56             Low          -0.118172

# %%
X = eq_data_2_adj[['change_in_lmarket', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change', 'liquidity']]
y = eq_data_2_adj['cs_change']
X = sm.add_constant(X)

model = PanelOLS(y, X, entity_effects=True, drop_absorbed=True).fit()
print(model.summary)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0006
# Estimator:                   PanelOLS   R-squared (Between):              0.0055
# No. Observations:               12992   R-squared (Within):               0.0006
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0013
# Time:                        17:14:05   Log-likelihood                 6.516e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.1117
# Entities:                         120   P-value                           0.0164
# Avg Obs:                       108.27   Distribution:                 F(2,12870)
# Min Obs:                       16.000
# Max Obs:                       197.00   F-statistic (robust):             4.1117
#                                         P-value                           0.0164
# Time periods:                     202   Distribution:                 F(2,12870)
# Avg Obs:                       64.317
# Min Obs:                       22.000
# Max Obs:                       120.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const              -7.15e-05  2.304e-05    -3.1034     0.0019     -0.0001  -2.634e-05
# change_in_lmarket -2.255e-06   3.17e-05    -0.0711     0.9433  -6.439e-05   5.989e-05
# liquidity          5.932e-05  2.074e-05     2.8606     0.0042   1.867e-05   9.997e-05
# =====================================================================================
#
# F-test for Poolability: 27.569
# P-value: 0.0000
# Distribution: F(119,12870)
#
# Included effects: Entity
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/3365734019.py:5: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y, X, entity_effects=True, drop_absorbed=True).fit()

# %%
results_by_returns_2 = {}
r_squared_table = {}

coef_table = pd.DataFrame()
for group_name, group_data in eq_data_2_adj.groupby('return_bucket'):
    y_group = group_data['cs_change']
    x_group = group_data[['change_in_lmarket', 'change_in_10y_bond', 'change_in_slope', 'smi_return', 'v3x_change', 'cpi_change', 'unempl_change', 'gdp_change', 'liquidity']]
    x_group = sm.add_constant(x_group)  
    model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
    
    coef = model.params
    coef.name = group_name
    coef_table = pd.concat([coef_table, coef], axis=1)
    
    
    print(f"\n\nResult for {group_name}")
    print(model.summary)
    
  
    results_by_returns_2[group_name] = model
    r_squared_table[group_name] = model.rsquared
    

coef_table = coef_table.T
# Out:
# Result for High
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):             -0.0119
# No. Observations:                3936   R-squared (Within):               0.0004
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0010
# Time:                        17:14:05   Log-likelihood                 2.204e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.7702
# Entities:                         119   P-value                           0.4630
# Avg Obs:                       33.076   Distribution:                  F(2,3815)
# Min Obs:                       1.0000
# Max Obs:                       127.00   F-statistic (robust):             0.7702
#                                         P-value                           0.4630
# Time periods:                     202   Distribution:                  F(2,3815)
# Avg Obs:                       19.485
# Min Obs:                       1.0000
# Max Obs:                       58.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const                -0.0001  2.367e-05    -4.3124     0.0000     -0.0001  -5.567e-05
# change_in_lmarket   1.35e-05  3.428e-05     0.3939     0.6937   -5.37e-05   8.071e-05
# liquidity         -2.447e-05   2.11e-05    -1.1595     0.2463  -6.583e-05    1.69e-05
# =====================================================================================
#
# F-test for Poolability: 24.704
# P-value: 0.0000
# Distribution: F(118,3815)
#
# Included effects: Entity
#
#
# Result for Low
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                        0.0189
# Estimator:                   PanelOLS   R-squared (Between):             -0.0429
# No. Observations:                3464   R-squared (Within):               0.0189
# Date:                Thu, May 15 2025   R-squared (Overall):              0.0357
# Time:                        17:14:05   Log-likelihood                 1.902e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      32.164
# Entities:                         115   P-value                           0.0000
# Avg Obs:                       30.122   Distribution:                  F(2,3347)
# Min Obs:                       1.0000
# Max Obs:                       142.00   F-statistic (robust):             32.164
#                                         P-value                           0.0000
# Time periods:                     202   Distribution:                  F(2,3347)
# Avg Obs:                       17.149
# Min Obs:                       2.0000
# Max Obs:                       44.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const               6.67e-06  2.876e-05     0.2319     0.8166  -4.973e-05   6.307e-05
# change_in_lmarket -1.187e-05  4.092e-05    -0.2901     0.7717  -9.211e-05   6.836e-05
# liquidity             0.0002  2.461e-05     7.9710     0.0000      0.0001      0.0002
# =====================================================================================
#
# F-test for Poolability: 18.770
# P-value: 0.0000
# Distribution: F(114,3347)
#
# Included effects: Entity
#
#
# Result for Medium
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              cs_change   R-squared:                     7.535e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0107
# No. Observations:                5592   R-squared (Within):            7.535e-05
# Date:                Thu, May 15 2025   R-squared (Overall):          -8.368e-06
# Time:                        17:14:05   Log-likelihood                 2.635e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.2061
# Entities:                         120   P-value                           0.8138
# Avg Obs:                       46.600   Distribution:                  F(2,5470)
# Min Obs:                       5.0000
# Max Obs:                       128.00   F-statistic (robust):             0.2061
#                                         P-value                           0.8138
# Time periods:                     202   Distribution:                  F(2,5470)
# Avg Obs:                       27.683
# Min Obs:                       3.0000
# Max Obs:                       83.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# const             -9.581e-05  4.821e-05    -1.9874     0.0469     -0.0002  -1.301e-06
# change_in_lmarket  1.581e-05  6.727e-05     0.2350     0.8142     -0.0001      0.0001
# liquidity          2.732e-05  4.511e-05     0.6056     0.5448  -6.111e-05      0.0001
# =====================================================================================
#
# F-test for Poolability: 6.7657
# P-value: 0.0000
# Distribution: F(119,5470)
#
# Included effects: Entity
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/2946626842.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/2946626842.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()
# /var/folders/dw/93tk385j54q9dmq3f082vbnm0000gn/T/ipykernel_94474/2946626842.py:9: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# change_in_10y_bond, change_in_slope, smi_return, v3x_change, cpi_change, unempl_change, gdp_change
#
#   model = PanelOLS(y_group, x_group, entity_effects=True, drop_absorbed=True).fit()

# %%
# Create R² DataFrame
r_squared_table = pd.Series(r_squared_table, name='R_squared')
# Print
print(r_squared_table)
# Out:
# High      0.000404
# Low       0.018857
# Medium    0.000075
# Name: R_squared, dtype: float64

# %%
eq_data_2_adj.to_csv("panel2_adj.csv")
